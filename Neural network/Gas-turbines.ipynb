# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda

from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
data=pd.read_csv('/drive/My Drive/neural-network/gas_turbines.csv')
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
sns.pairplot(data)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#splitting into x and y
x=data.drop(labels='TEY',axis=1)
y=data['TEY']
x
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_norm = norm_func(x)

# %%
model = Sequential()
model.add(Dense(12, input_dim=10, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_norm, y, epochs=50, batch_size=10)
# Out:
# Epoch 1/50
# 1504/1504 [==============================] - 5s 2ms/step - loss: -106994.4062 - accuracy: 0.0000e+00
# Epoch 2/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: -1418117.1250 - accuracy: 0.0000e+00
# Epoch 3/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -5072584.0000 - accuracy: 0.0000e+00
# Epoch 4/50
# 1504/1504 [==============================] - 6s 4ms/step - loss: -11570130.0000 - accuracy: 0.0000e+00
# Epoch 5/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -21328126.0000 - accuracy: 0.0000e+00
# Epoch 6/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -34786368.0000 - accuracy: 0.0000e+00
# Epoch 7/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -52396044.0000 - accuracy: 0.0000e+00
# Epoch 8/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -74607760.0000 - accuracy: 0.0000e+00
# Epoch 9/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -101851504.0000 - accuracy: 0.0000e+00
# Epoch 10/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -134597216.0000 - accuracy: 0.0000e+00
# Epoch 11/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -173259072.0000 - accuracy: 0.0000e+00
# Epoch 12/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -218293952.0000 - accuracy: 0.0000e+00
# Epoch 13/50
# 1504/1504 [==============================] - 4s 3ms/step - loss: -270122176.0000 - accuracy: 0.0000e+00
# Epoch 14/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -329160320.0000 - accuracy: 0.0000e+00
# Epoch 15/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -395844320.0000 - accuracy: 0.0000e+00
# Epoch 16/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -470661312.0000 - accuracy: 0.0000e+00
# Epoch 17/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -553984512.0000 - accuracy: 0.0000e+00
# Epoch 18/50
# 1504/1504 [==============================] - 4s 2ms/step - loss: -646190016.0000 - accuracy: 0.0000e+00
# Epoch 19/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -747784320.0000 - accuracy: 0.0000e+00
# Epoch 20/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -859186880.0000 - accuracy: 0.0000e+00
# Epoch 21/50
# 1504/1504 [==============================] - 4s 3ms/step - loss: -980802432.0000 - accuracy: 0.0000e+00
# Epoch 22/50
# 1504/1504 [==============================] - 4s 2ms/step - loss: -1113048192.0000 - accuracy: 0.0000e+00
# Epoch 23/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -1256365824.0000 - accuracy: 0.0000e+00
# Epoch 24/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -1411158912.0000 - accuracy: 0.0000e+00
# Epoch 25/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -1577747968.0000 - accuracy: 0.0000e+00
# Epoch 26/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -1756718464.0000 - accuracy: 0.0000e+00
# Epoch 27/50
# 1504/1504 [==============================] - 4s 3ms/step - loss: -1948414592.0000 - accuracy: 0.0000e+00
# Epoch 28/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -2153206784.0000 - accuracy: 0.0000e+00
# Epoch 29/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -2371517696.0000 - accuracy: 0.0000e+00
# Epoch 30/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -2603858432.0000 - accuracy: 0.0000e+00
# Epoch 31/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -2850506496.0000 - accuracy: 0.0000e+00
# Epoch 32/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -3111993344.0000 - accuracy: 0.0000e+00
# Epoch 33/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -3388690944.0000 - accuracy: 0.0000e+00
# Epoch 34/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -3681099008.0000 - accuracy: 0.0000e+00
# Epoch 35/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -3989498624.0000 - accuracy: 0.0000e+00
# Epoch 36/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -4314264576.0000 - accuracy: 0.0000e+00
# Epoch 37/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -4655969792.0000 - accuracy: 0.0000e+00
# Epoch 38/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -5014936064.0000 - accuracy: 0.0000e+00
# Epoch 39/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -5391613440.0000 - accuracy: 0.0000e+00
# Epoch 40/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -5786359296.0000 - accuracy: 0.0000e+00
# Epoch 41/50
# 1504/1504 [==============================] - 4s 2ms/step - loss: -6199507968.0000 - accuracy: 0.0000e+00
# Epoch 42/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -6631636480.0000 - accuracy: 0.0000e+00
# Epoch 43/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -7083284992.0000 - accuracy: 0.0000e+00
# Epoch 44/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -7554514944.0000 - accuracy: 0.0000e+00
# Epoch 45/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -8045950976.0000 - accuracy: 0.0000e+00
# Epoch 46/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: -8557933056.0000 - accuracy: 0.0000e+00
# Epoch 47/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -9091003392.0000 - accuracy: 0.0000e+00
# Epoch 48/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -9645526016.0000 - accuracy: 0.0000e+00
# Epoch 49/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -10221844480.0000 - accuracy: 0.0000e+00
# Epoch 50/50
# 1504/1504 [==============================] - 3s 2ms/step - loss: -10820197376.0000 - accuracy: 0.0000e+00

# %%
accuracy = model.evaluate(x, y)
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: -5145631391744.0000 - accuracy: 0.0000e+00
